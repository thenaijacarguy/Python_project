# %%
import pandas as pd

# %%
df = pd.read_csv('Sample Data.csv', encoding='latin')

# %%
df
# Out:
#                 City  Customer Age      Customer Name Customer Segment  \
# 0         McKeesport           NaN     Jessica Myrick   Small Business
# 1              Bowie           NaN     Matt Collister      Home Office
# 2               Napa           NaN  Alan Schoenberger        Corporate
# 3         Montebello           NaN  Elizabeth Moffitt         Consumer
# 4               Napa           NaN  Alan Schoenberger        Corporate
# ...              ...           ...                ...              ...
# 8394       Fairfield          95.0      Tony Molinari        Corporate
# 8395  Harker Heights          95.0    Matt Hagelstein      Home Office
# 8396       Riverview          95.0      Theresa Swint         Consumer
# 8397   Nicholasville          95.0    Maribeth Yedwab      Home Office
# 8398   Nicholasville          95.0    Maribeth Yedwab      Home Office
#
#       Discount  Number of Records  Order Date  Order ID Order Priority  \
# ...

# %%
df['Customer Age'].mean()
# Out:
# 54.542822838847385

# %%
import numpy as np

# %%
df['Customer Age'] =df['Customer Age'].replace(np.NaN, df['Customer Age'].mean())

# %%
df
# Out:
#                 City  Customer Age      Customer Name Customer Segment  \
# 0         McKeesport     54.542823     Jessica Myrick   Small Business
# 1              Bowie     54.542823     Matt Collister      Home Office
# 2               Napa     54.542823  Alan Schoenberger        Corporate
# 3         Montebello     54.542823  Elizabeth Moffitt         Consumer
# 4               Napa     54.542823  Alan Schoenberger        Corporate
# ...              ...           ...                ...              ...
# 8394       Fairfield     95.000000      Tony Molinari        Corporate
# 8395  Harker Heights     95.000000    Matt Hagelstein      Home Office
# 8396       Riverview     95.000000      Theresa Swint         Consumer
# 8397   Nicholasville     95.000000    Maribeth Yedwab      Home Office
# 8398   Nicholasville     95.000000    Maribeth Yedwab      Home Office
#
#       Discount  Number of Records  Order Date  Order ID Order Priority  \
# ...

# %%
df['Customer Age'] = df['Customer Age'].astype(int)

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#                 city  customer age      customer name customer segment  \
# 0         McKeesport            54     Jessica Myrick   Small Business
# 1              Bowie            54     Matt Collister      Home Office
# 2               Napa            54  Alan Schoenberger        Corporate
# 3         Montebello            54  Elizabeth Moffitt         Consumer
# 4               Napa            54  Alan Schoenberger        Corporate
# ...              ...           ...                ...              ...
# 8394       Fairfield            95      Tony Molinari        Corporate
# 8395  Harker Heights            95    Matt Hagelstein      Home Office
# 8396       Riverview            95      Theresa Swint         Consumer
# 8397   Nicholasville            95    Maribeth Yedwab      Home Office
# 8398   Nicholasville            95    Maribeth Yedwab      Home Office
#
#       discount  number of records  order date  order id order priority  \
# ...

# %%
import seaborn as sns

# %%
sns.histplot(data=df, x='customer age');

# %%
sns.countplot(data=df, y='customer segment', color='black');
